# %%
#!/usr/bin/env python

# --------------------------------------------------------
# Py Faster R-CNN train notebook 
# based on py-faster-rcnn Written by Ross Girshick from Microsoft (MIT License)
# Edited by Joris GUERRY from ONERA
# --------------------------------------------------------

"""Train a Faster R-CNN network using alternating optimization.
This tool implements the alternating optimization algorithm described in our
NIPS 2015 paper ("Faster R-CNN: Towards Real-time Object Detection with Region
Proposal Networks." Shaoqing Ren, Kaiming He, Ross Girshick, Jian Sun.)
"""

import _init_paths
from fast_rcnn.train import get_training_roidb, train_net
from fast_rcnn.config import cfg, cfg_from_file, cfg_from_list, get_output_dir
from datasets.factory import get_imdb
from rpn.generate import imdb_proposals
import argparse
import pprint
import numpy as np
import sys, os
import multiprocessing as mp
import cPickle
import shutil

# %%
def get_roidb(imdb_name, rpn_file=None):
    print 'Requiring dataset `{:s}` for training'.format(imdb_name)
    imdb = get_imdb(imdb_name)
    print 'Loaded dataset `{:s}` for training'.format(imdb.name)
    imdb.set_proposal_method(cfg.TRAIN.PROPOSAL_METHOD)
    print 'Set proposal method: {:s}'.format(cfg.TRAIN.PROPOSAL_METHOD)
    if rpn_file is not None:
        imdb.config['rpn_file'] = rpn_file
    roidb = get_training_roidb(imdb)
    return roidb, imdb

# %%
def get_solvers(net_name):
    # Faster R-CNN Alternating Optimization
    n = 'faster_rcnn_alt_opt'
    # Solver for each training stage
    solvers = [[net_name, n, 'stage1_rpn_solver60k80k.pt'],
               [net_name, n, 'stage1_fast_rcnn_solver30k40k.pt'],
               [net_name, n, 'stage2_rpn_solver60k80k.pt'],
               [net_name, n, 'stage2_fast_rcnn_solver30k40k.pt']]
    solvers = [os.path.join(cfg.MODELS_DIR, *s) for s in solvers]
    # Iterations for each training stage
    #max_iters = [80000, 40000, 80000, 40000]
    max_iters = [100, 100, 100, 100]
    # Test prototxt for the RPN
    rpn_test_prototxt = os.path.join(
        cfg.MODELS_DIR, net_name, n, 'rpn_test.pt')
    return solvers, max_iters, rpn_test_prototxt

# %%
def _init_caffe(cfg):
    """Initialize pycaffe in a training process.
    """

    import caffe
    # fix the random seeds (numpy and caffe) for reproducibility
    np.random.seed(cfg.RNG_SEED)
    caffe.set_random_seed(cfg.RNG_SEED)
    # set up caffe
    caffe.set_mode_gpu()
    caffe.set_device(cfg.GPU_ID)

# %%
class Args:
    def __init__(self,
                 gpu_id=0,
                 net_name='VGG_CNN_M_1024',
                 pretrained_model='/data/workspace/jg_pfr/data/imagenet_models/VGG_CNN_M_1024.v2.caffemodel',
                 cfg_file='/data/workspace/jg_pfr/experiments/cfgs/faster_rcnn_alt_opt.yml',
                 imdb_name= 'voc_2007_fake',
                 set_cfgs=None):
        
        self.gpu_id = gpu_id
        self.net_name = net_name
        self.pretrained_model = pretrained_model
        self.cfg_file = cfg_file
        self.imdb_name = imdb_name
        self.set_cfgs = set_cfgs
    
args = Args()

if args.cfg_file is not None:
    cfg_from_file(args.cfg_file)
if args.set_cfgs is not None:
    cfg_from_list(args.set_cfgs)
cfg.GPU_ID = args.gpu_id

#pprint.pprint(cfg)

# %%
# solves, iters, etc. for each training stage
solvers, max_iters, rpn_test_prototxt = get_solvers(args.net_name)

# %%
print '~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~'
print 'Stage 1.1 RPN, init from ImageNet model'
print '~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~'

"""Train a Region Proposal Network in a separate training process.
"""

# Not using any proposals, just ground-truth boxes
cfg.TRAIN.HAS_RPN = True
cfg.TRAIN.BBOX_REG = False  # applies only to Fast R-CNN bbox regression
cfg.TRAIN.PROPOSAL_METHOD = 'gt'
cfg.TRAIN.IMS_PER_BATCH = 1
print 'Init model: {}'.format(args.pretrained_model)
print('Using config:')
pprint.pprint(cfg)

import caffe
_init_caffe(cfg)

roidb, imdb = get_roidb(args.imdb_name)
print 'roidb len: {}'.format(len(roidb))
output_dir = get_output_dir(imdb)
print 'Output will be saved to `{:s}`'.format(output_dir)

model_paths = train_net(solvers[0], roidb, output_dir,
                        pretrained_model=args.pretrained_model,
                        max_iters=max_iters[0])

# Cleanup all but the final model
for i in model_paths[:-1]:
    os.remove(i)
rpn_model_path = str(model_paths[-1])
# Out:
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Stage 1.1 RPN, init from ImageNet model
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Init model: /data/workspace/jg_pfr/data/imagenet_models/VGG_CNN_M_1024.v2.caffemodel
# Using config:
# {'DATA_DIR': '/data/workspace/jg_pfr/data',
#  'DEDUP_BOXES': 0.0625,
#  'EPS': 1e-14,
#  'EXP_DIR': 'faster_rcnn_alt_opt',
#  'GPU_ID': 0,
#  'MATLAB': 'matlab',
#  'MODELS_DIR': '/data/workspace/jg_pfr/models/pascal_voc',
#  'PIXEL_MEANS': array([[[ 102.9801,  115.9465,  122.7717]]]),
#  'RNG_SEED': 3,
#  'ROOT_DIR': '/data/workspace/jg_pfr',
#  'TEST': {'BBOX_REG': True,
#           'HAS_RPN': True,
#           'MAX_SIZE': 1000,
#           'NMS': 0.3,
#           'PROPOSAL_METHOD': 'selective_search',
#           'RPN_MIN_SIZE': 16,
#           'RPN_NMS_THRESH': 0.7,
#           'RPN_POST_NMS_TOP_N': 300,
#           'RPN_PRE_NMS_TOP_N': 6000,
#           'SCALES': [600],
#           'SVM': False},
#  'TRAIN': {'ASPECT_GROUPING': True,
#            'BATCH_SIZE': 128,
#            'BBOX_INSIDE_WEIGHTS': [1.0, 1.0, 1.0, 1.0],
#            'BBOX_NORMALIZE_MEANS': [0.0, 0.0, 0.0, 0.0],
#            'BBOX_NORMALIZE_STDS': [0.1, 0.1, 0.2, 0.2],
#            'BBOX_NORMALIZE_TARGETS': True,
#            'BBOX_NORMALIZE_TARGETS_PRECOMPUTED': False,
#            'BBOX_REG': False,
#            'BBOX_THRESH': 0.5,
#            'BG_THRESH_HI': 0.5,
#            'BG_THRESH_LO': 0.0,
#            'FG_FRACTION': 0.25,
#            'FG_THRESH': 0.5,
#            'HAS_RPN': True,
#            'IMS_PER_BATCH': 1,
#            'MAX_SIZE': 1000,
#            'PROPOSAL_METHOD': 'gt',
#            'RPN_BATCHSIZE': 256,
#            'RPN_BBOX_INSIDE_WEIGHTS': [1.0, 1.0, 1.0, 1.0],
#            'RPN_CLOBBER_POSITIVES': False,
#            'RPN_FG_FRACTION': 0.5,
#            'RPN_MIN_SIZE': 16,
#            'RPN_NEGATIVE_OVERLAP': 0.3,
#            'RPN_NMS_THRESH': 0.7,
#            'RPN_POSITIVE_OVERLAP': 0.7,
#            'RPN_POSITIVE_WEIGHT': -1.0,
#            'RPN_POST_NMS_TOP_N': 2000,
#            'RPN_PRE_NMS_TOP_N': 12000,
#            'SCALES': [600],
#            'SNAPSHOT_INFIX': '',
#            'SNAPSHOT_ITERS': 10000,
#            'USE_FLIPPED': True,
#            'USE_PREFETCH': False},
#  'USE_GPU_NMS': True}
# Requiring dataset `voc_2007_fake` for training
# Loaded dataset `voc_2007_fake` for training
# Set proposal method: gt
# Appending horizontally-flipped training examples...
# voc_2007_fake gt roidb loaded from /data/workspace/jg_pfr/data/cache/voc_2007_fake_gt_roidb.pkl
# done
# Preparing training data...
# done
# roidb len: 200
# Output will be saved to `/data/workspace/jg_pfr/output/faster_rcnn_alt_opt/voc_2007_fake`
# Filtered 0 roidb entries: 200 -> 200
# RoiDataLayer: name_to_top: {'gt_boxes': 2, 'data': 0, 'im_info': 1}
# Loading pretrained model weights from /data/workspace/jg_pfr/data/imagenet_models/VGG_CNN_M_1024.v2.caffemodel
# Solving...
# Wrote snapshot to: /data/workspace/jg_pfr/output/faster_rcnn_alt_opt/voc_2007_fake/vgg_cnn_m_1024_rpn_iter_100.caffemodel
# done solving

# %%
#rpn_model_path = '/data/workspace/jg_pfr/output/faster_rcnn_alt_opt/voc_2007_val/vgg_cnn_m_1024_rpn_iter_100.caffemodel'

# %%
print '~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~'
print 'Stage 1.2 RPN, generate proposals'
print '~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~'

cfg.TEST.RPN_PRE_NMS_TOP_N = -1     # no pre NMS filtering
cfg.TEST.RPN_POST_NMS_TOP_N = 2000  # limit top boxes after NMS
print 'RPN model: {}'.format(rpn_model_path)
print('Using config:')
pprint.pprint(cfg)

import caffe
_init_caffe(cfg)

# NOTE: the matlab implementation computes proposals on flipped images, too.
# We compute them on the image once and then flip the already computed
# proposals. This might cause a minor loss in mAP (less proposal jittering).
imdb = get_imdb(args.imdb_name)
print 'Loaded dataset `{:s}` for proposal generation'.format(imdb.name)

# Load RPN and configure output directory
rpn_net = caffe.Net(rpn_test_prototxt, rpn_model_path, caffe.TEST)
output_dir = get_output_dir(imdb)
print 'Output will be saved to `{:s}`'.format(output_dir)

# Generate proposals on the imdb
rpn_proposals = imdb_proposals(rpn_net, imdb)

# Write proposals to disk
rpn_net_name = os.path.splitext(os.path.basename(rpn_model_path))[0]
rpn_proposals_path = os.path.join(
    output_dir, rpn_net_name + '_proposals.pkl')
with open(rpn_proposals_path, 'wb') as f:
    cPickle.dump(rpn_proposals, f, cPickle.HIGHEST_PROTOCOL)
print 'Wrote RPN proposals to {}'.format(rpn_proposals_path)
print "Number of images : "+ str(len(rpn_proposals))
print "Number of BB proposal : "+ str((rpn_proposals[0]).shape[0])
# Out:
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Stage 1.2 RPN, generate proposals
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# RPN model: /data/workspace/jg_pfr/output/faster_rcnn_alt_opt/voc_2007_fake/vgg_cnn_m_1024_rpn_iter_100.caffemodel
# Using config:
# {'DATA_DIR': '/data/workspace/jg_pfr/data',
#  'DEDUP_BOXES': 0.0625,
#  'EPS': 1e-14,
#  'EXP_DIR': 'faster_rcnn_alt_opt',
#  'GPU_ID': 0,
#  'MATLAB': 'matlab',
#  'MODELS_DIR': '/data/workspace/jg_pfr/models/pascal_voc',
#  'PIXEL_MEANS': array([[[ 102.9801,  115.9465,  122.7717]]]),
#  'RNG_SEED': 3,
#  'ROOT_DIR': '/data/workspace/jg_pfr',
#  'TEST': {'BBOX_REG': True,
#           'HAS_RPN': True,
#           'MAX_SIZE': 1000,
#           'NMS': 0.3,
#           'PROPOSAL_METHOD': 'selective_search',
#           'RPN_MIN_SIZE': 16,
#           'RPN_NMS_THRESH': 0.7,
#           'RPN_POST_NMS_TOP_N': 2000,
#           'RPN_PRE_NMS_TOP_N': -1,
#           'SCALES': [600],
#           'SVM': False},
#  'TRAIN': {'ASPECT_GROUPING': True,
#            'BATCH_SIZE': 128,
#            'BBOX_INSIDE_WEIGHTS': [1.0, 1.0, 1.0, 1.0],
#            'BBOX_NORMALIZE_MEANS': [0.0, 0.0, 0.0, 0.0],
#            'BBOX_NORMALIZE_STDS': [0.1, 0.1, 0.2, 0.2],
#            'BBOX_NORMALIZE_TARGETS': True,
#            'BBOX_NORMALIZE_TARGETS_PRECOMPUTED': False,
#            'BBOX_REG': False,
#            'BBOX_THRESH': 0.5,
#            'BG_THRESH_HI': 0.5,
#            'BG_THRESH_LO': 0.0,
#            'FG_FRACTION': 0.25,
#            'FG_THRESH': 0.5,
#            'HAS_RPN': True,
#            'IMS_PER_BATCH': 1,
#            'MAX_SIZE': 1000,
#            'PROPOSAL_METHOD': 'gt',
#            'RPN_BATCHSIZE': 256,
#            'RPN_BBOX_INSIDE_WEIGHTS': [1.0, 1.0, 1.0, 1.0],
#            'RPN_CLOBBER_POSITIVES': False,
#            'RPN_FG_FRACTION': 0.5,
#            'RPN_MIN_SIZE': 16,
#            'RPN_NEGATIVE_OVERLAP': 0.3,
#            'RPN_NMS_THRESH': 0.7,
#            'RPN_POSITIVE_OVERLAP': 0.7,
#            'RPN_POSITIVE_WEIGHT': -1.0,
#            'RPN_POST_NMS_TOP_N': 2000,
#            'RPN_PRE_NMS_TOP_N': 12000,
#            'SCALES': [600],
#            'SNAPSHOT_INFIX': '',
#            'SNAPSHOT_ITERS': 10000,
#            'USE_FLIPPED': True,
#            'USE_PREFETCH': False},
#  'USE_GPU_NMS': True}
# Loaded dataset `voc_2007_fake` for proposal generation
# Output will be saved to `/data/workspace/jg_pfr/output/faster_rcnn_alt_opt/voc_2007_fake`
# im_proposals: 1/100 1.292s
# im_proposals: 2/100 0.693s
# im_proposals: 3/100 0.482s
# im_proposals: 4/100 0.378s
# im_proposals: 5/100 0.313s
# im_proposals: 6/100 0.271s
# im_proposals: 7/100 0.242s
# im_proposals: 8/100 0.220s
# im_proposals: 9/100 0.201s
# im_proposals: 10/100 0.185s
# im_proposals: 11/100 0.174s
# im_proposals: 12/100 0.165s
# im_proposals: 13/100 0.155s
# im_proposals: 14/100 0.148s
# im_proposals: 15/100 0.142s
# im_proposals: 16/100 0.137s
# im_proposals: 17/100 0.131s
# im_proposals: 18/100 0.128s
# im_proposals: 19/100 0.125s
# im_proposals: 20/100 0.122s
# im_proposals: 21/100 0.119s
# im_proposals: 22/100 0.117s
# im_proposals: 23/100 0.114s
# im_proposals: 24/100 0.112s
# im_proposals: 25/100 0.109s
# im_proposals: 26/100 0.107s
# im_proposals: 27/100 0.104s
# im_proposals: 28/100 0.102s
# im_proposals: 29/100 0.101s
# im_proposals: 30/100 0.099s
# im_proposals: 31/100 0.097s
# im_proposals: 32/100 0.096s
# im_proposals: 33/100 0.094s
# im_proposals: 34/100 0.093s
# im_proposals: 35/100 0.091s
# im_proposals: 36/100 0.090s
# im_proposals: 37/100 0.089s
# im_proposals: 38/100 0.088s
# im_proposals: 39/100 0.087s
# im_proposals: 40/100 0.086s
# im_proposals: 41/100 0.085s
# im_proposals: 42/100 0.085s
# im_proposals: 43/100 0.084s
# im_proposals: 44/100 0.083s
# im_proposals: 45/100 0.082s
# im_proposals: 46/100 0.081s
# im_proposals: 47/100 0.081s
# im_proposals: 48/100 0.080s
# im_proposals: 49/100 0.079s
# im_proposals: 50/100 0.079s
# im_proposals: 51/100 0.078s
# im_proposals: 52/100 0.078s
# im_proposals: 53/100 0.077s
# im_proposals: 54/100 0.077s
# im_proposals: 55/100 0.076s
# im_proposals: 56/100 0.076s
# im_proposals: 57/100 0.075s
# im_proposals: 58/100 0.075s
# im_proposals: 59/100 0.074s
# im_proposals: 60/100 0.074s
# im_proposals: 61/100 0.073s
# im_proposals: 62/100 0.073s
# im_proposals: 63/100 0.073s
# im_proposals: 64/100 0.072s
# im_proposals: 65/100 0.072s
# im_proposals: 66/100 0.071s
# im_proposals: 67/100 0.071s
# im_proposals: 68/100 0.071s
# im_proposals: 69/100 0.070s
# im_proposals: 70/100 0.070s
# im_proposals: 71/100 0.070s
# im_proposals: 72/100 0.069s
# im_proposals: 73/100 0.069s
# im_proposals: 74/100 0.069s
# im_proposals: 75/100 0.069s
# im_proposals: 76/100 0.069s
# im_proposals: 77/100 0.068s
# im_proposals: 78/100 0.068s
# im_proposals: 79/100 0.068s
# im_proposals: 80/100 0.068s
# im_proposals: 81/100 0.067s
# im_proposals: 82/100 0.067s
# im_proposals: 83/100 0.067s
# im_proposals: 84/100 0.067s
# im_proposals: 85/100 0.067s
# im_proposals: 86/100 0.066s
# im_proposals: 87/100 0.066s
# im_proposals: 88/100 0.066s
# im_proposals: 89/100 0.066s
# im_proposals: 90/100 0.066s
# im_proposals: 91/100 0.066s
# im_proposals: 92/100 0.066s
# im_proposals: 93/100 0.066s
# im_proposals: 94/100 0.066s
# im_proposals: 95/100 0.066s
# im_proposals: 96/100 0.065s
# im_proposals: 97/100 0.065s
# im_proposals: 98/100 0.065s
# im_proposals: 99/100 0.065s
# im_proposals: 100/100 0.065s
# Wrote RPN proposals to /data/workspace/jg_pfr/output/faster_rcnn_alt_opt/voc_2007_fake/vgg_cnn_m_1024_rpn_iter_100_proposals.pkl
# Number of images : 100
# Number of BB proposal : 2000

# %%
#rpn_proposals_path = '/data/workspace/jg_pfr/output/faster_rcnn_alt_opt/voc_2007_val/vgg_cnn_m_1024_rpn_iter_100_proposals.pkl'

# %%
print '~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~'
print 'Stage 1.3 Fast R-CNN using RPN proposals, init from ImageNet model'
print '~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~'

cfg.TRAIN.SNAPSHOT_INFIX = 'stage1'
cfg.TRAIN.HAS_RPN = False           # not generating prosals on-the-fly
cfg.TRAIN.PROPOSAL_METHOD = 'rpn'   # use pre-computed RPN proposals instead
cfg.TRAIN.IMS_PER_BATCH = 2
print 'Init model: {}'.format(args.pretrained_model)
print 'RPN proposals: {}'.format(rpn_proposals_path)
print('Using config:')
pprint.pprint(cfg)

import caffe
_init_caffe(cfg)

roidb, imdb = get_roidb(args.imdb_name, rpn_file=rpn_proposals_path)
output_dir = get_output_dir(imdb)
print 'Output will be saved to `{:s}`'.format(output_dir)
# Out:
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Stage 1.3 Fast R-CNN using RPN proposals, init from ImageNet model
# ~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~
# Init model: /data/workspace/jg_pfr/data/imagenet_models/VGG_CNN_M_1024.v2.caffemodel
# RPN proposals: /data/workspace/jg_pfr/output/faster_rcnn_alt_opt/voc_2007_fake/vgg_cnn_m_1024_rpn_iter_100_proposals.pkl
# Using config:
# {'DATA_DIR': '/data/workspace/jg_pfr/data',
#  'DEDUP_BOXES': 0.0625,
#  'EPS': 1e-14,
#  'EXP_DIR': 'faster_rcnn_alt_opt',
#  'GPU_ID': 0,
#  'MATLAB': 'matlab',
#  'MODELS_DIR': '/data/workspace/jg_pfr/models/pascal_voc',
#  'PIXEL_MEANS': array([[[ 102.9801,  115.9465,  122.7717]]]),
#  'RNG_SEED': 3,
#  'ROOT_DIR': '/data/workspace/jg_pfr',
#  'TEST': {'BBOX_REG': True,
#           'HAS_RPN': True,
#           'MAX_SIZE': 1000,
#           'NMS': 0.3,
#           'PROPOSAL_METHOD': 'selective_search',
#           'RPN_MIN_SIZE': 16,
#           'RPN_NMS_THRESH': 0.7,
#           'RPN_POST_NMS_TOP_N': 2000,
#           'RPN_PRE_NMS_TOP_N': -1,
#           'SCALES': [600],
#           'SVM': False},
#  'TRAIN': {'ASPECT_GROUPING': True,
#            'BATCH_SIZE': 128,
#            'BBOX_INSIDE_WEIGHTS': [1.0, 1.0, 1.0, 1.0],
#            'BBOX_NORMALIZE_MEANS': [0.0, 0.0, 0.0, 0.0],
#            'BBOX_NORMALIZE_STDS': [0.1, 0.1, 0.2, 0.2],
#            'BBOX_NORMALIZE_TARGETS': True,
#            'BBOX_NORMALIZE_TARGETS_PRECOMPUTED': False,
#            'BBOX_REG': False,
#            'BBOX_THRESH': 0.5,
#            'BG_THRESH_HI': 0.5,
#            'BG_THRESH_LO': 0.0,
#            'FG_FRACTION': 0.25,
#            'FG_THRESH': 0.5,
#            'HAS_RPN': False,
#            'IMS_PER_BATCH': 2,
#            'MAX_SIZE': 1000,
#            'PROPOSAL_METHOD': 'rpn',
#            'RPN_BATCHSIZE': 256,
#            'RPN_BBOX_INSIDE_WEIGHTS': [1.0, 1.0, 1.0, 1.0],
#            'RPN_CLOBBER_POSITIVES': False,
#            'RPN_FG_FRACTION': 0.5,
#            'RPN_MIN_SIZE': 16,
#            'RPN_NEGATIVE_OVERLAP': 0.3,
#            'RPN_NMS_THRESH': 0.7,
#            'RPN_POSITIVE_OVERLAP': 0.7,
#            'RPN_POSITIVE_WEIGHT': -1.0,
#            'RPN_POST_NMS_TOP_N': 2000,
#            'RPN_PRE_NMS_TOP_N': 12000,
#            'SCALES': [600],
#            'SNAPSHOT_INFIX': 'stage1',
#            'SNAPSHOT_ITERS': 10000,
#            'USE_FLIPPED': True,
#            'USE_PREFETCH': False},
#  'USE_GPU_NMS': True}
# Requiring dataset `voc_2007_fake` for training
# Loaded dataset `voc_2007_fake` for training
# Set proposal method: rpn
# Appending horizontally-flipped training examples...
# voc_2007_fake gt roidb loaded from /data/workspace/jg_pfr/data/cache/voc_2007_fake_gt_roidb.pkl
# loading /data/workspace/jg_pfr/output/faster_rcnn_alt_opt/voc_2007_fake/vgg_cnn_m_1024_rpn_iter_100_proposals.pkl
# done
# Preparing training data...
# done
# Output will be saved to `/data/workspace/jg_pfr/output/faster_rcnn_alt_opt/voc_2007_fake`

# %%
print solvers[1]
print output_dir
print args.pretrained_model
print max_iters[1]
# Out:
# /data/workspace/jg_pfr/models/pascal_voc/VGG_CNN_M_1024/faster_rcnn_alt_opt/stage1_fast_rcnn_solver30k40k.pt
# /data/workspace/jg_pfr/output/faster_rcnn_alt_opt/voc_2007_fake
# /data/workspace/jg_pfr/data/imagenet_models/VGG_CNN_M_1024.v2.caffemodel
# 100

# %%
pprint.pprint(cfg)
# Out:
# {'DATA_DIR': '/data/workspace/jg_pfr/data',
#  'DEDUP_BOXES': 0.0625,
#  'EPS': 1e-14,
#  'EXP_DIR': 'faster_rcnn_alt_opt',
#  'GPU_ID': 0,
#  'MATLAB': 'matlab',
#  'MODELS_DIR': '/data/workspace/jg_pfr/models/pascal_voc',
#  'PIXEL_MEANS': array([[[ 102.9801,  115.9465,  122.7717]]]),
#  'RNG_SEED': 3,
#  'ROOT_DIR': '/data/workspace/jg_pfr',
#  'TEST': {'BBOX_REG': True,
#           'HAS_RPN': True,
#           'MAX_SIZE': 1000,
#           'NMS': 0.3,
#           'PROPOSAL_METHOD': 'selective_search',
#           'RPN_MIN_SIZE': 16,
#           'RPN_NMS_THRESH': 0.7,
#           'RPN_POST_NMS_TOP_N': 2000,
#           'RPN_PRE_NMS_TOP_N': -1,
#           'SCALES': [600],
#           'SVM': False},
#  'TRAIN': {'ASPECT_GROUPING': True,
#            'BATCH_SIZE': 128,
#            'BBOX_INSIDE_WEIGHTS': [1.0, 1.0, 1.0, 1.0],
#            'BBOX_NORMALIZE_MEANS': [0.0, 0.0, 0.0, 0.0],
#            'BBOX_NORMALIZE_STDS': [0.1, 0.1, 0.2, 0.2],
#            'BBOX_NORMALIZE_TARGETS': True,
#            'BBOX_NORMALIZE_TARGETS_PRECOMPUTED': False,
#            'BBOX_REG': False,
#            'BBOX_THRESH': 0.5,
#            'BG_THRESH_HI': 0.5,
#            'BG_THRESH_LO': 0.0,
#            'FG_FRACTION': 0.25,
#            'FG_THRESH': 0.5,
#            'HAS_RPN': False,
#            'IMS_PER_BATCH': 2,
#            'MAX_SIZE': 1000,
#            'PROPOSAL_METHOD': 'rpn',
#            'RPN_BATCHSIZE': 256,
#            'RPN_BBOX_INSIDE_WEIGHTS': [1.0, 1.0, 1.0, 1.0],
#            'RPN_CLOBBER_POSITIVES': False,
#            'RPN_FG_FRACTION': 0.5,
#            'RPN_MIN_SIZE': 16,
#            'RPN_NEGATIVE_OVERLAP': 0.3,
#            'RPN_NMS_THRESH': 0.7,
#            'RPN_POSITIVE_OVERLAP': 0.7,
#            'RPN_POSITIVE_WEIGHT': -1.0,
#            'RPN_POST_NMS_TOP_N': 2000,
#            'RPN_PRE_NMS_TOP_N': 12000,
#            'SCALES': [600],
#            'SNAPSHOT_INFIX': 'stage1',
#            'SNAPSHOT_ITERS': 10000,
#            'USE_FLIPPED': True,
#            'USE_PREFETCH': False},
#  'USE_GPU_NMS': True}

# %%
# Train Fast R-CNN
model_paths = train_net(solvers[1], roidb, output_dir,
                        pretrained_model=args.pretrained_model,
                        max_iters=max_iters[1])
# Cleanup all but the final model
for i in model_paths[:-1]:
    os.remove(i)
fast_rcnn_model_path = model_paths[-1]
# Send Fast R-CNN model path over the multiprocessing queue
#queue.put({'model_path': fast_rcnn_model_path})
# Out:
# Filtered 0 roidb entries: 200 -> 200
# RoiDataLayer: name_to_top: {'rois': 1, 'labels': 2, 'data': 0}
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# <ipython-input-14-722a9cab64a4> in <module>()
#       2 model_paths = train_net(solvers[1], roidb, output_dir,
#       3                         pretrained_model=args.pretrained_model,
# ----> 4                         max_iters=max_iters[1])
#       5 # Cleanup all but the final model
#       6 for i in model_paths[:-1]:
#
# /data/workspace/jg_pfr/lib/fast_rcnn/train.pyc in train_net(solver_prototxt, roidb, output_dir, pretrained_model, max_iters)
#     155     roidb = filter_roidb(roidb)
#     156     sw = SolverWrapper(solver_prototxt, roidb, output_dir,
# --> 157                        pretrained_model=pretrained_model)
#     158
#     159     print 'Solving...'
#
# /data/workspace/jg_pfr/lib/fast_rcnn/train.pyc in __init__(self, solver_prototxt, roidb, output_dir, pretrained_model)
#      41             print 'done'
#      42
# ---> 43         self.solver = caffe.SGDSolver(solver_prototxt)
#      44         if pretrained_model is not None:
#      45             print ('Loading pretrained model '
#
# /data/workspace/jg_pfr/lib/roi_data_layer/layer.pyc in setup(self, bottom, top)
#     138
#     139         print 'RoiDataLayer: name_to_top:', self._name_to_top_map
# --> 140         assert len(top) == len(self._name_to_top_map)
#     141
#     142     def forward(self, bottom, top):
#
# AssertionError:

# %%
stoooooooooooooooooooooooooooop here Jack !

# %% [raw]
# # --------------------------------------------------------------------------
# # Pycaffe doesn't reliably free GPU memory when instantiated nets are
# # discarded (e.g. "del net" in Python code). To work around this issue, each
# # training stage is executed in a separate process using
# # multiprocessing.Process.
# # --------------------------------------------------------------------------
#
# # queue for communicated results between processes
# mp_queue = mp.Queue()

# %% [raw]
#     print '~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~'
#     print 'Stage 1 RPN, init from ImageNet model'
#     print '~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~'
#
#     cfg.TRAIN.SNAPSHOT_INFIX = 'stage1'
#     mp_kwargs = dict(
#             queue=mp_queue,
#             imdb_name=args.imdb_name,
#             init_model=args.pretrained_model,
#             solver=solvers[0],
#             max_iters=max_iters[0],
#             cfg=cfg)
#     p = mp.Process(target=train_rpn, kwargs=mp_kwargs)
#     p.start()
#     rpn_stage1_out = mp_queue.get()
#     p.join()

# %% [raw]
# print '~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~'
# print 'Stage 1 RPN, generate proposals'
# print '~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~'
#
# mp_kwargs = dict(
#         queue=mp_queue,
#         imdb_name=args.imdb_name,
#         rpn_model_path=str(rpn_stage1_out['model_path']),
#         cfg=cfg,
#         rpn_test_prototxt=rpn_test_prototxt)
# p = mp.Process(target=rpn_generate, kwargs=mp_kwargs)
# p.start()
# rpn_stage1_out['proposal_path'] = mp_queue.get()['proposal_path']
# p.join()

# %% [raw]
# print '~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~'
# print 'Stage 1 Fast R-CNN using RPN proposals, init from ImageNet model'
# print '~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~'
#
# cfg.TRAIN.SNAPSHOT_INFIX = 'stage1'
# mp_kwargs = dict(
#         queue=mp_queue,
#         imdb_name=args.imdb_name,
#         init_model=args.pretrained_model,
#         solver=solvers[1],
#         max_iters=max_iters[1],
#         cfg=cfg,
#         rpn_file=rpn_stage1_out['proposal_path'])
# p = mp.Process(target=train_fast_rcnn, kwargs=mp_kwargs)
# p.start()
# fast_rcnn_stage1_out = mp_queue.get()
# p.join()

# %%
print '~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~'
print 'Stage 2 RPN, init from stage 1 Fast R-CNN model'
print '~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~'

cfg.TRAIN.SNAPSHOT_INFIX = 'stage2'
mp_kwargs = dict(
        queue=mp_queue,
        imdb_name=args.imdb_name,
        init_model=str(fast_rcnn_stage1_out['model_path']),
        solver=solvers[2],
        max_iters=max_iters[2],
        cfg=cfg)
p = mp.Process(target=train_rpn, kwargs=mp_kwargs)
p.start()
rpn_stage2_out = mp_queue.get()
p.join()

# %%
print '~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~'
print 'Stage 2 RPN, generate proposals'
print '~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~'

mp_kwargs = dict(
        queue=mp_queue,
        imdb_name=args.imdb_name,
        rpn_model_path=str(rpn_stage2_out['model_path']),
        cfg=cfg,
        rpn_test_prototxt=rpn_test_prototxt)
p = mp.Process(target=rpn_generate, kwargs=mp_kwargs)
p.start()
rpn_stage2_out['proposal_path'] = mp_queue.get()['proposal_path']
p.join()

# %%
print '~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~'
print 'Stage 2 Fast R-CNN, init from stage 2 RPN R-CNN model'
print '~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~~'

cfg.TRAIN.SNAPSHOT_INFIX = 'stage2'
mp_kwargs = dict(
        queue=mp_queue,
        imdb_name=args.imdb_name,
        init_model=str(rpn_stage2_out['model_path']),
        solver=solvers[3],
        max_iters=max_iters[3],
        cfg=cfg,
        rpn_file=rpn_stage2_out['proposal_path'])
p = mp.Process(target=train_fast_rcnn, kwargs=mp_kwargs)
p.start()
fast_rcnn_stage2_out = mp_queue.get()
p.join()

# %%
# Create final model (just a copy of the last stage)
final_path = os.path.join(
        os.path.dirname(fast_rcnn_stage2_out['model_path']),
        args.net_name + '_faster_rcnn_final.caffemodel')
print 'cp {} -> {}'.format(
        fast_rcnn_stage2_out['model_path'], final_path)
shutil.copy(fast_rcnn_stage2_out['model_path'], final_path)
print 'Final model: {}'.format(final_path)

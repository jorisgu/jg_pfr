# %% [markdown]
# # les classiques

# %%
name = {}
i=0
for year in ['v1', 'v2']:
    for split in [  'testGupta',
                    'trainGupta',
                    'valGupta',
                    'trainvalGupta']:

        for chanel in [ 'd_raw_DNA_8bits',
                        'd_raw_focus_8bits',
                        'd_raw_focus_16bits',
                        'd_raw_normal_8bits',
                        'd_raw_normal_16bits',
                        'd_raw_HHA_8bits',
                        'd_raw_jet_8bits',
                        'd_raw_cubehelix_8bits',
                        'd_raw_histeqBack_8bits',
                        'd_raw_histeqBack_16bits',
                        'd_raw_histeqFront_8bits',
                        'd_raw_histeqFront_16bits',
                        'd_raw_histeqRandom_8bits',
                        'd_raw_histeqRandom_16bits',
                        'rgb_i_10_8bits',
                        'rgb_i_20_8bits',
                        'rgb_i_30_8bits',
                        'rgb_i_40_8bits',
                        'rgb_i_50_8bits',
                        'rgb_i_60_8bits',
                        'rgb_i_70_8bits',
                        'rgb_i_80_8bits',
                        'rgb_i_90_8bits',
                        'rgb_i_100_8bits']:
            name[i] = 'nyud_{}_{}_{}'.format(year, split, chanel)
            i=i+1

# %%
name
# Out:
# {0: 'nyud_v1_testGupta_d_raw_DNA_8bits',
#  1: 'nyud_v1_testGupta_d_raw_focus_8bits',
#  2: 'nyud_v1_testGupta_d_raw_focus_16bits',
#  3: 'nyud_v1_testGupta_d_raw_normal_8bits',
#  4: 'nyud_v1_testGupta_d_raw_normal_16bits',
#  5: 'nyud_v1_testGupta_d_raw_HHA_8bits',
#  6: 'nyud_v1_testGupta_d_raw_jet_8bits',
#  7: 'nyud_v1_testGupta_d_raw_cubehelix_8bits',
#  8: 'nyud_v1_testGupta_d_raw_histeqBack_8bits',
#  9: 'nyud_v1_testGupta_d_raw_histeqBack_16bits',
#  10: 'nyud_v1_testGupta_d_raw_histeqFront_8bits',
#  11: 'nyud_v1_testGupta_d_raw_histeqFront_16bits',
#  12: 'nyud_v1_testGupta_d_raw_histeqRandom_8bits',
#  13: 'nyud_v1_testGupta_d_raw_histeqRandom_16bits',
#  14: 'nyud_v1_testGupta_rgb_i_10_8bits',
#  15: 'nyud_v1_testGupta_rgb_i_20_8bits',
#  16: 'nyud_v1_testGupta_rgb_i_30_8bits',
#  17: 'nyud_v1_testGupta_rgb_i_40_8bits',
#  18: 'nyud_v1_testGupta_rgb_i_50_8bits',
#  19: 'nyud_v1_testGupta_rgb_i_60_8bits',
#  20: 'nyud_v1_testGupta_rgb_i_70_8bits',
# ...

# %%
for year in ['v1', 'v2']:
    for split in [  'testGupta',
                    'trainGupta',
                    'valGupta',
                    'trainvalGupta',

                    'testGupta_i_all',
                    'trainGupta_i_all',
                    'valGupta_i_all',
                    'trainvalGupta_i_all',

                    'testGupta_i_r_100_60',
                    'trainGupta_i_r_100_60',
                    'valGupta_i_r_100_60',
                    'trainvalGupta_i_r_100_60',

                    'testGupta_i_r_50_10',
                    'trainGupta_i_r_50_10',
                    'valGupta_i_r_50_10',
                    'trainvalGupta_i_r_50_10']:

        for chanel in [ 'd_raw_DNA_8bits',
                        'd_raw_focus_8bits',
                        'd_raw_focus_16bits',
                        'd_raw_normal_8bits',
                        'd_raw_normal_16bits',
                        'd_raw_HHA_8bits',
                        'd_raw_jet_8bits',
                        'd_raw_cubehelix_8bits',
                        'd_raw_histeqBack_8bits',
                        'd_raw_histeqBack_16bits',
                        'd_raw_histeqFront_8bits',
                        'd_raw_histeqFront_16bits',
                        'd_raw_histeqRandom_8bits',
                        'd_raw_histeqRandom_16bits',
                        'rgb_i_10_8bits',
                        'rgb_i_20_8bits',
                        'rgb_i_30_8bits',
                        'rgb_i_40_8bits',
                        'rgb_i_50_8bits',
                        'rgb_i_60_8bits',
                        'rgb_i_70_8bits',
                        'rgb_i_80_8bits',
                        'rgb_i_90_8bits',
                        'rgb_i_100_8bits',
                        'rgb_i_r_100_60_8bits',
                        'rgb_i_r_50_10_8bits',
                        'rgb_i_all_8bits']:
            name[i] = 'nyud_{}_{}_{}'.format(year, split, chanel)
            i=i+1
# Out:
# {0: 'nyud_v1_testGupta_d_raw_DNA_8bits',
#  1: 'nyud_v1_testGupta_d_raw_focus_8bits',
#  2: 'nyud_v1_testGupta_d_raw_focus_16bits',
#  3: 'nyud_v1_testGupta_d_raw_normal_8bits',
#  4: 'nyud_v1_testGupta_d_raw_normal_16bits',
#  5: 'nyud_v1_testGupta_d_raw_HHA_8bits',
#  6: 'nyud_v1_testGupta_d_raw_jet_8bits',
#  7: 'nyud_v1_testGupta_d_raw_cubehelix_8bits',
#  8: 'nyud_v1_testGupta_d_raw_HHA_focus_8bits',
#  9: 'nyud_v1_testGupta_d_raw_jet_focus_8bits',
#  10: 'nyud_v1_testGupta_d_raw_cubehelix_focus_8bits',
#  11: 'nyud_v1_testGupta_d_raw_histeqBack_8bits',
#  12: 'nyud_v1_testGupta_d_raw_histeqBack_16bits',
#  13: 'nyud_v1_testGupta_d_raw_histeqFront_8bits',
#  14: 'nyud_v1_testGupta_d_raw_histeqFront_16bits',
#  15: 'nyud_v1_testGupta_d_raw_histeqRandom_8bits',
#  16: 'nyud_v1_testGupta_d_raw_histeqRandom_16bits',
#  17: 'nyud_v1_testGupta_rgb_i_10_8bits',
#  18: 'nyud_v1_testGupta_rgb_i_20_8bits',
#  19: 'nyud_v1_testGupta_rgb_i_30_8bits',
# ...

# %%
for year in ['v1', 'v2']:
    for split in [  'testGupta',
                    'trainGupta',
                    'valGupta',
                    'trainvalGupta',

                    'testGupta_i_all',
                    'trainGupta_i_all',
                    'valGupta_i_all',
                    'trainvalGupta_i_all',

                    'testGupta_i_r_100_60',
                    'trainGupta_i_r_100_60',
                    'valGupta_i_r_100_60',
                    'trainvalGupta_i_r_100_60',

                    'testGupta_i_r_50_10',
                    'trainGupta_i_r_50_10',
                    'valGupta_i_r_50_10',
                    'trainvalGupta_i_r_50_10']:

        for chanel in [ 'd_raw_DNA_8bits',
                        'd_raw_focus_8bits',
                        'd_raw_focus_16bits',
                        'd_raw_normal_8bits',
                        'd_raw_normal_16bits',
                        'd_raw_HHA_8bits',
                        'd_raw_jet_8bits',
                        'd_raw_cubehelix_8bits',
                        'd_raw_histeqBack_8bits',
                        'd_raw_histeqBack_16bits',
                        'd_raw_histeqFront_8bits',
                        'd_raw_histeqFront_16bits',
                        'd_raw_histeqRandom_8bits',
                        'd_raw_histeqRandom_16bits',
                        'rgb_i_10_8bits',
                        'rgb_i_20_8bits',
                        'rgb_i_30_8bits',
                        'rgb_i_40_8bits',
                        'rgb_i_50_8bits',
                        'rgb_i_60_8bits',
                        'rgb_i_70_8bits',
                        'rgb_i_80_8bits',
                        'rgb_i_90_8bits',
                        'rgb_i_100_8bits',
                        'rgb_i_r_100_60_8bits',
                        'rgb_i_r_50_10_8bits',
                        'rgb_i_all_8bits']:
            name[i] = 'nyud_{}_{}_{}'.format(year, split, chanel)
            i=i+1
